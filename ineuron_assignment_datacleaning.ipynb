# %%
import pandas as pd
import numpy as np

# %%
# problem statement
df = pd.DataFrame({'From_To': ['LoNDon_paris', 'MAdrid_miLAN',
'londON_StockhOlm',
'Budapest_PaRis', 'Brussels_londOn'],
'FlightNumber': [10045, np.nan, 10065, np.nan, 10085],
'RecentDelays': [[23, 47], [], [24, 43, 87], [13], [67, 32]],
'Airline': ['KLM(!)', '<Air France> (12)', '(British Airways. )',
'12. Air France', '"Swiss Air"']})

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN           NaN            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis           NaN          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
# filling up the missing values with 0 
#df['FlightNumber']=df['FlightNumber'].replace(np.nan,0)
# but here filling the nan values with the specified values

# %%
df['FlightNumber'].fillna(value=df['FlightNumber'][0]+10, limit=1, inplace=True)
df['FlightNumber'].fillna(value=df['FlightNumber'][2]+10, limit=1, inplace=True)
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris       10045.0      [23, 47]               KLM(!)
# 1      MAdrid_miLAN       10055.0            []    <Air France> (12)
# 2  londON_StockhOlm       10065.0  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis       10075.0          [13]       12. Air France
# 4   Brussels_londOn       10085.0      [67, 32]          "Swiss Air"

# %%
# converting the data column type from float tp integers 
df['FlightNumber']=df['FlightNumber'].astype(int)

# %%
df
# Out:
#             From_To  FlightNumber  RecentDelays              Airline
# 0      LoNDon_paris         10045      [23, 47]               KLM(!)
# 1      MAdrid_miLAN         10055            []    <Air France> (12)
# 2  londON_StockhOlm         10065  [24, 43, 87]  (British Airways. )
# 3    Budapest_PaRis         10075          [13]       12. Air France
# 4   Brussels_londOn         10085      [67, 32]          "Swiss Air"

# %%
# 2)Separating the from and to columns

# %%
x= pd.DataFrame(df['From_To'].str.split('_', 1).to_list(), columns = ['From','To'])

# %%
x
# Out:
#        From         To
# 0    LoNDon      paris
# 1    MAdrid      miLAN
# 2    londON  StockhOlm
# 3  Budapest      PaRis
# 4  Brussels     londOn

# %%
# storing the separated df in another variable and then capitalizing the elements

# %%
x['From'] =x['From'].str.capitalize()
x['To'] = x['To'].str.capitalize()

# %%
x
# Out:
#        From         To
# 0    London      Paris
# 1    Madrid      Milan
# 2    London  Stockholm
# 3  Budapest      Paris
# 4  Brussels     London

# %%
df.drop(['From_To'],inplace=True,axis=1)

# %%
df
# Out:
#    FlightNumber  RecentDelays              Airline
# 0         10045      [23, 47]               KLM(!)
# 1         10055            []    <Air France> (12)
# 2         10065  [24, 43, 87]  (British Airways. )
# 3         10075          [13]       12. Air France
# 4         10085      [67, 32]          "Swiss Air"

# %%
df1= pd.concat([x,df],axis=1,sort=False)

# %%
df1
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    London      Paris         10045      [23, 47]               KLM(!)
# 1    Madrid      Milan         10055            []    <Air France> (12)
# 2    London  Stockholm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      Paris         10075          [13]       12. Air France
# 4  Brussels     London         10085      [67, 32]          "Swiss Air"

# %%
df=df1
df
# Out:
#        From         To  FlightNumber  RecentDelays              Airline
# 0    London      Paris         10045      [23, 47]               KLM(!)
# 1    Madrid      Milan         10055            []    <Air France> (12)
# 2    London  Stockholm         10065  [24, 43, 87]  (British Airways. )
# 3  Budapest      Paris         10075          [13]       12. Air France
# 4  Brussels     London         10085      [67, 32]          "Swiss Air"

# %%
# SEPARAYING THE DELAYS 
delay= pd.DataFrame(df['RecentDelays'].to_list(),columns=['delay_1', 'delay_2', 'delay_3'])
delay
# Out:
#    delay_1  delay_2  delay_3
# 0     23.0     47.0      NaN
# 1      NaN      NaN      NaN
# 2     24.0     43.0     87.0
# 3     13.0      NaN      NaN
# 4     67.0     32.0      NaN

# %%
df.drop(['RecentDelays'], inplace=True, axis=1)
df
# Out:
#        From         To  FlightNumber              Airline
# 0    London      Paris         10045               KLM(!)
# 1    Madrid      Milan         10055    <Air France> (12)
# 2    London  Stockholm         10065  (British Airways. )
# 3  Budapest      Paris         10075       12. Air France
# 4  Brussels     London         10085          "Swiss Air"

# %%
df.insert(loc = 3, column='delay_1' , value=delay['delay_1'])
df.insert(loc = 4, column='delay_2' , value=delay['delay_2'])
df.insert(loc = 5, column='delay_3' , value=delay['delay_3'])
df
# Out:
#        From         To  FlightNumber  delay_1  delay_2  delay_3  \
# 0    London      Paris         10045     23.0     47.0      NaN
# 1    Madrid      Milan         10055      NaN      NaN      NaN
# 2    London  Stockholm         10065     24.0     43.0     87.0
# 3  Budapest      Paris         10075     13.0      NaN      NaN
# 4  Brussels     London         10085     67.0     32.0      NaN
#
#                Airline
# 0               KLM(!)
# 1    <Air France> (12)
# 2  (British Airways. )
# 3       12. Air France
# 4          "Swiss Air"
